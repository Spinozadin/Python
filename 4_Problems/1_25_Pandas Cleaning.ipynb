# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_25_Pandas Cleaning.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !pip install datasets
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %% [markdown]
# ---

# %%
df.sort_values(by='job_posted_date', ascending=True, inplace=True)
df

# %% [markdown]
# ## 🟩 Sort by Salary (1.25.1)

# %%
df.sort_values(by='salary_year_avg', ascending=False, inplace=True)
df.head(10)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Create Remote Column (1.25.2)

# %%
df['Is Data Analyst'] = (df.job_title_short == 'Data Analyst').astype(int)
df[df['Is Data Analyst'] > 0]
# Out:
#        job_title_short         job_title    job_location            job_via  \
# 108804    Data Analyst      Data Analyst    New York, NY  via CareerBuilder
# 96906     Data Analyst      Data Analyst  Bloomfield, CT  via CareerBuilder
# 98438     Data Analyst      Data Analyst  Washington, DC  via CareerBuilder
# 110290    Data Analyst      Data Analyst     Fairfax, VA  via CareerBuilder
# 104526    Data Analyst  Jr. Data Analyst    Torrance, CA    via Recruit.net
# ...                ...               ...             ...                ...
# 369494    Data Analyst      Data analyst      Dallas, TX     via Talent.com
# 358704    Data Analyst      Data analyst    Chandler, AZ     via Talent.com
# 326336    Data Analyst      Data analyst      Topeka, KS     via Talent.com
# 358496    Data Analyst      Data analyst       Hobbs, NM     via Talent.com
# 356798    Data Analyst      Data analyst     Gilbert, AZ     via Talent.com
#
#        job_schedule_type  job_work_from_home            search_location  \
# 108804         Full-time               False    New York, United States
# 96906          Full-time               False    New York, United States
# 98438          Full-time               False    New York, United States
# 110290         Full-time               False    New York, United States
# 104526         Full-time               False  California, United States
# ...                  ...                 ...                        ...
# 369494         Full-time               False                      Sudan
# 358704         Full-time               False                      Sudan
# 326336         Full-time               False                      Sudan
# 358496         Full-time               False                      Sudan
# 356798         Full-time               False                      Sudan
#
#             job_posted_date  job_no_degree_mention  job_health_insurance  \
# 108804  2023-01-01 00:00:04                  False                 False
# 96906   2023-01-01 00:00:07                   True                 False
# 98438   2023-01-01 00:00:22                  False                  True
# 110290  2023-01-01 00:00:24                  False                 False
# 104526  2023-01-01 00:00:38                  False                 False
# ...                     ...                    ...                   ...
# 369494  2023-12-31 23:40:03                   True                 False
# 358704  2023-12-31 23:40:07                   True                 False
# 326336  2023-12-31 23:40:07                   True                 False
# 358496  2023-12-31 23:40:10                   True                 False
# 356798  2023-12-31 23:40:10                   True                 False
#
#           job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 108804  United States        None              NaN              NaN
# 96906   United States        None              NaN              NaN
# 98438   United States        None              NaN              NaN
# 110290  United States        None              NaN              NaN
# 104526  United States        None              NaN              NaN
# ...               ...         ...              ...              ...
# 369494          Sudan        None              NaN              NaN
# 358704          Sudan        None              NaN              NaN
# 326336          Sudan        None              NaN              NaN
# 358496          Sudan        None              NaN              NaN
# 356798          Sudan        None              NaN              NaN
#
#                                    company_name  \
# 108804                     Metasys Technologies
# 96906                              Diverse Lynx
# 98438                                Guidehouse
# 110290                                  Protask
# 104526                                   Aquent
# ...                                         ...
# 369494  Dental Imaging Technologies Corporation
# 358704                                 FlexJobs
# 326336                                 FlexJobs
# 358496                                 FlexJobs
# 356798                                 FlexJobs
#
#                                                job_skills  \
# 108804  ['sql', 'snowflake', 'visio', 'jira', 'conflue...
# 96906                               ['sql', 'sas', 'sas']
# 98438   ['sql', 'python', 'r', 'azure', 'snowflake', '...
# 110290                                    ['sql', 'jira']
# 104526                                          ['excel']
# ...                                                   ...
# 369494                                               None
# 358704                                               None
# 326336                                               None
# 358496                                               None
# 356798                                               None
#
#                                           job_type_skills  Is Data Analyst
# 108804  {'analyst_tools': ['visio'], 'async': ['jira',...                1
# 96906   {'analyst_tools': ['sas'], 'programming': ['sq...                1
# 98438   {'analyst_tools': ['tableau', 'excel'], 'cloud...                1
# 110290        {'async': ['jira'], 'programming': ['sql']}                1
# 104526                       {'analyst_tools': ['excel']}                1
# ...                                                   ...              ...
# 369494                                               None                1
# 358704                                               None                1
# 326336                                               None                1
# 358496                                               None                1
# 356798                                               None                1
#
# [196075 rows x 18 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Extract Year from Date (1.25.3)

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Drop Missing Salaries (1.25.4)

# %% [markdown]
# ---
