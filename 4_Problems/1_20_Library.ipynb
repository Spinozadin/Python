# %% [markdown]
# <a href="https://colab.research.google.com/github/Spinozadin/Python/blob/main/4_Problems/1_20_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/1_20_Library.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## 🟩 List Installed Packages (1.20.1)

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- -------------------
# absl-py                          1.4.0
# accelerate                       0.34.2
# aiohappyeyeballs                 2.4.0
# aiohttp                          3.10.5
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albucore                         0.0.16
# albumentations                   1.4.15
# altair                           4.2.2
# annotated-types                  0.7.0
# anyio                            3.7.1
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array_record                     0.5.1
# arviz                            0.19.0
# astropy                          6.1.3
# astropy-iers-data                0.2024.9.16.0.32.21
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.1.0
# attrs                            24.2.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Install and Verify Library (1.20.2)

# %%
# !pip install pyjokes
import pyjokes

pyjokes.get_joke()
# Out:
# ...
# 'Failure is not an option. It comes bundled with your Microsoft product.'

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 List Files in Directory (1.20.3)

# %%
import os

# %%
files = os.listdir('.')
for file in files:
  print(file)
# Out:
# .config
# sample_data

# %% [markdown]
# ---

# %% [markdown]
# ## 🟥 Fetch Data from URL (1.20.4)

# %%
# Code Needed
url = 'https://pokeapi.co/api/v2/pokemon/pikachu'

import requests

url = 'https://pokeapi.co/api/v2/pokemon/pikachu'

response = requests.get(url)
data = response.json()
print(data)
# Out:
# {'abilities': [{'ability': {'name': 'static', 'url': 'https://pokeapi.co/api/v2/ability/9/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'lightning-rod', 'url': 'https://pokeapi.co/api/v2/ability/31/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 112, 'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/25.ogg', 'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/25.ogg'}, 'forms': [{'name': 'pikachu', 'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}], 'game_indices': [{'game_index': 84, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 84, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 84, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 25, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 25, 'version': {'name': 'sil
# ...

# %% [markdown]
# ---
